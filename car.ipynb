# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df=pd.read_csv("cars_data_clean.csv",index_col=[0])

# %%
df.head()
# Out:
#                                                 loc  myear       body  \
# usedCarSkuId
# 7111bf25-97af-47f9-867b-40879190d800    gomti nagar   2016  hatchback
# c309efc1-efaf-4f82-81ad-dcb38eb36665  borivali west   2015  hatchback
# 7609f710-0c97-4f00-9a47-9b9284b62d3a         jasola   2015      sedan
# 278b76e3-5539-4a5e-ae3e-353a2e3b6d7d         jasola   2013  hatchback
# b1eab99b-a606-48dd-a75b-57feb8a9ad92  mumbai g.p.o.   2022        muv
#
#                                      transmission fuel        km  ip  \
# usedCarSkuId
# 7111bf25-97af-47f9-867b-40879190d800       manual  cng   69162.0   0
# c309efc1-efaf-4f82-81ad-dcb38eb36665       manual  cng   45864.0   0
# 7609f710-0c97-4f00-9a47-9b9284b62d3a       manual  cng   81506.0   0
# 278b76e3-5539-4a5e-ae3e-353a2e3b6d7d       manual  cng  115893.0   0
# b1eab99b-a606-48dd-a75b-57feb8a9ad92       manual  cng   18900.0   0
#
#                                                                                  images  \
# ...
